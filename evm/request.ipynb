# %%
import requests
from html import unescape
import re
import pandas as pd

# %%
def get_data(section):
    """
    Makes get request to the respective section of the eVM,
    fixes html encodings and returns the (html) text
    """
    
    url = f"https://evm.min-saude.pt/table?t={section}&s=0"
    response = requests.get(url)
    response.encoding = 'utf-8'
    text = unescape(response.text)
    return(text)


def parse_single_tab(text):
    """
    Uses regular expressions to retrieve the data and columns used to create the html table.
    Imports data and columns to a pandas dataframe
    """
    
    data = re.search('\"data\":(\[\[.+\]\])', text).group(1)
    data = re.findall('(\[[^[]+\])[,\]]', data)
    data = [re.findall("\[(.+)\]", x)[0].split(',') for x in data]
    columns = re.findall('<th>(.+?)<\\\\/th>', text)

    df = pd.DataFrame(data).T  
    df.columns=columns
    
    return df

def parse_multiple_tabs(text):
    """
    For pages with a tab structure (one tab / ano)
    Calls parse_single_tab for each tab, adds a column with respective year and saves all
    to a single pandas dataframe
    """

    tabs = re.findall('\<(div\sclass=\"tab-pane\"\sdata-value=\"20\d\d.+?(?=\/table))',
                      text, re.DOTALL)
    tmp = []
    for t in tabs:
        
        df = parse_single_tab(t)
        year = re.findall('data-value="(\d{4})"\s', t)
        assert(len(year) == 1)
        df['Ano'] = year[0]
        
        tmp.append(df)

    return pd.concat(tmp)

# %% [markdown]
# ## Geral

# %%
raw = get_data('geral')
parse_single_tab(raw)
# Out:
#          Data 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019  2020
# 0    "Jan-01"  423  318  384  379  339  375  407  366  475  414  371   376
# 1    "Jan-02"  435  364  357  357  343  394  413  314  578  418  386   381
# 2    "Jan-03"  416  357  370  356  352  399  416  339  479  450  367   374
# 3    "Jan-04"  380  322  350  362  321  327  466  348  501  425  371   364
# 4    "Jan-05"  446  334  368  354  342  359  452  329  493  434  367   333
# ..        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 361  "Dez-27"  328  333  329  312  346  331  326  467  426  342  350  null
# 362  "Dez-28"  381  353  339  285  356  358  355  439  421  338  318  null
# 363  "Dez-29"  374  387  351  307  343  374  306  454  389  347  354  null
# 364  "Dez-30"  372  352  328  279  358  358  327  464  352  342  339  null
# 365  "Dez-31"  335  379  327  320  360  382  323  470  390  357  345  null
#
# [366 rows x 13 columns]

# %% [markdown]
# ## Causas

# %%
raw = get_data('causas')
parse_multiple_tabs(raw)
# Out:
#     Data (mm-dd) Morte natural Causa externa Sujeito a investigação   Ano
# 0       "Jan-01"           333             5                     37  2014
# 1       "Jan-02"           329            10                     55  2014
# 2       "Jan-03"           354             7                     38  2014
# 3       "Jan-04"           299             2                     26  2014
# 4       "Jan-05"           327             2                     30  2014
# ..           ...           ...           ...                    ...   ...
# 360     "Dez-27"           316             2                     32  2019
# 361     "Dez-28"           285             3                     30  2019
# 362     "Dez-29"           310             7                     37  2019
# 363     "Dez-30"           300             7                     32  2019
# 364     "Dez-31"           300             9                     36  2019
#
# [2191 rows x 5 columns]

# %% [markdown]
# ## Grupo etário

# %%
raw = get_data('idades')
parse_multiple_tabs(raw)
# Out:
#     Data (mm-dd) < 1 ano 1-4 anos 5-14 anos 15-24 anos 25-34 anos 35-44 anos  \
# 0       "Jan-01"       0        0         0          1          2          7
# 1       "Jan-02"       0        0         2          0          2          6
# 2       "Jan-03"       2        0         1          1          6          7
# 3       "Jan-04"       1        0         0          1          1          5
# 4       "Jan-05"       0        0         0          0          3          2
# ..           ...     ...      ...       ...        ...        ...        ...
# 360     "Dez-27"       1        0         1          1          1          3
# 361     "Dez-28"       1        1         0          0          1          4
# 362     "Dez-29"       1        0         0          2          1          4
# 363     "Dez-30"       0        0         2          1          3          6
# 364     "Dez-31"       1        0         1          2          0          5
#
#     45-54 anos 55-64 anos 65-74 anos 75-84 anos ≥ 85 anos Desconhecido   Ano
# 0           13         27         60        118       147            0  2014
# 1           18         27         71        126       142            0  2014
# 2           20         35         61        109       157            0  2014
# 3           20         23         47         97       132            0  2014
# 4           15         32         54        114       139            0  2014
# ..         ...        ...        ...        ...       ...          ...   ...
# 360         11         34         52        104       142            0  2019
# 361          6         16         43         91       154            1  2019
# 362         16         27         59        107       135            2  2019
# 363         15         26         62         72       152            0  2019
# 364         16         20         41         97       161            1  2019
#
# [2191 rows x 14 columns]

# %% [markdown]
# ## Por causa externa

# %%
raw = get_data('externas')
parse_multiple_tabs(raw)
# Out:
#     Data (mm-dd) Acidente de trânsito Acidente de trabalho Eventual suicídio  \
# 0       "Jan-01"                    2                    0                 2
# 1       "Jan-02"                    1                    0                 4
# 2       "Jan-03"                    0                    0                 4
# 3       "Jan-04"                    0                    0                 1
# 4       "Jan-05"                    0                    0                 0
# ..           ...                  ...                  ...               ...
# 360     "Dez-27"                    0                    0                 0
# 361     "Dez-28"                    0                    0                 1
# 362     "Dez-29"                    2                    0                 2
# 363     "Dez-30"                    2                    1                 2
# 364     "Dez-31"                    2                    0                 2
#
#     Eventual homicídio Outro acidente Ignorado   Ano
# 0                    0              1        0  2014
# 1                    0              3        2  2014
# 2                    0              2        1  2014
# 3                    0              0        1  2014
# 4                    0              2        0  2014
# ..                 ...            ...      ...   ...
# 360                  1              1        0  2019
# 361                  1              0        1  2019
# 362                  1              2        0  2019
# 363                  0              2        0  2019
# 364                  1              4        0  2019
#
# [2191 rows x 8 columns]

# %% [markdown]
# ## Local de óbito

# %%
raw = get_data('local')
raw = raw.replace('Instituic?o de Saude', 'Instituição de Saúde')
raw = raw.replace('domicilio', 'domicílio')
parse_multiple_tabs(raw)
# Out:
#     Data (mm-dd) Desconhecido Na Instituição de Saúde No domicílio  \
# 0       "Jan-01"            5                     231           99
# 1       "Jan-02"           15                     229          105
# 2       "Jan-03"            6                     252          107
# 3       "Jan-04"            2                     204           94
# 4       "Jan-05"            3                     223           96
# ..           ...          ...                     ...          ...
# 360     "Dez-27"            0                     219           89
# 361     "Dez-28"            1                     188           83
# 362     "Dez-29"            1                     226           95
# 363     "Dez-30"            1                     199          101
# 364     "Dez-31"            8                     212           82
#
#     Outro local   Ano
# 0            40  2014
# 1            45  2014
# 2            34  2014
# 3            27  2014
# 4            37  2014
# ..          ...   ...
# 360          42  2019
# 361          46  2019
# 362          32  2019
# 363          38  2019
# 364          43  2019
#
# [2191 rows x 6 columns]

# %% [markdown]
# ## Agrupamento de Centro de Saúde

# %%
raw = get_data('ACES')
parse_multiple_tabs(raw)
# Out:
#       Data (mm-dd)                     ACES Óbitos   Ano
# 0         "Jan-01"  "ACES Alentejo Central"      4  2014
# 1         "Jan-02"  "ACES Alentejo Central"      7  2014
# 2         "Jan-03"  "ACES Alentejo Central"      8  2014
# 3         "Jan-04"  "ACES Alentejo Central"      8  2014
# 4         "Jan-05"  "ACES Alentejo Central"      7  2014
# ...            ...                      ...    ...   ...
# 31750     "Dez-27"    "Pinhal Interior Sul"      2  2019
# 31751     "Dez-28"    "Pinhal Interior Sul"      2  2019
# 31752     "Dez-29"    "Pinhal Interior Sul"      4  2019
# 31753     "Dez-30"    "Pinhal Interior Sul"      2  2019
# 31754     "Dez-31"    "Pinhal Interior Sul"      2  2019
#
# [190617 rows x 4 columns]

# %% [markdown]
# ## Distrito

# %%
raw = get_data('distrito')
parse_multiple_tabs(raw)
# Out:
#       Data (mm-dd)  Distrito Óbitos   Ano
# 0         "Jan-01"  "Aveiro"     28  2014
# 1         "Jan-02"  "Aveiro"     23  2014
# 2         "Jan-03"  "Aveiro"     20  2014
# 3         "Jan-04"  "Aveiro"     19  2014
# 4         "Jan-05"  "Aveiro"     19  2014
# ...            ...       ...    ...   ...
# 11310     "Dez-27"   "Viseu"      9  2019
# 11311     "Dez-28"   "Viseu"     11  2019
# 11312     "Dez-29"   "Viseu"     11  2019
# 11313     "Dez-30"   "Viseu"     14  2019
# 11314     "Dez-31"   "Viseu"     10  2019
#
# [67921 rows x 4 columns]

# %% [markdown]
# # Not working properly

# %%
raw = get_data('concelho')
parse_multiple_tabs(raw)
# Out:
#                  Concelho Semana 01-2014 Semana 02-2014 Semana 03-2014  \
# 0              "Abrantes"             10             15             10
# 1                "Águeda"              7             13             10
# 2       "Aguiar da Beira"              2              3              1
# 3             "Alandroal"              2              1              1
# 4    "Albergaria-a-Velha"              6              9              4
# ..                    ...            ...            ...            ...
# 305             "Vimioso"            NaN            NaN            NaN
# 306             "Vinhais"            NaN            NaN            NaN
# 307               "Viseu"            NaN            NaN            NaN
# 308              "Vizela"            NaN            NaN            NaN
# 309             "Vouzela"            NaN            NaN            NaN
#
#     Semana 04-2014 Semana 05-2014 Semana 06-2014 Semana 07-2014  \
# 0               15             16             17             12
# 1                5             12             12              7
# 2                3              2              3              5
# 3                2              0              2              3
# 4                7              3              9              2
# ..             ...            ...            ...            ...
# 305            NaN            NaN            NaN            NaN
# 306            NaN            NaN            NaN            NaN
# 307            NaN            NaN            NaN            NaN
# 308            NaN            NaN            NaN            NaN
# 309            NaN            NaN            NaN            NaN
#
#     Semana 08-2014 Semana 09-2014  ... Semana 44-2019 Semana 45-2019  \
# 0               13              8  ...            NaN            NaN
# 1                9              8  ...            NaN            NaN
# 2                4              3  ...            NaN            NaN
# 3                3              4  ...            NaN            NaN
# 4                5             10  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 305            NaN            NaN  ...              1              2
# 306            NaN            NaN  ...              3              5
# 307            NaN            NaN  ...             17             14
# 308            NaN            NaN  ...              2              2
# 309            NaN            NaN  ...              2              0
#
#     Semana 46-2019 Semana 47-2019 Semana 48-2019 Semana 49-2019  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 305              3              4              2              1
# 306              2              2              2              2
# 307             18             30             15             16
# 308              3              0              1              2
# 309              4              0              5              1
#
#     Semana 50-2019 Semana 51-2019 Semana 52-2019 Semana 01-2020
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 305              1              1              2              3
# 306              3              1              5              2
# 307             15             12             14              2
# 308              3              7              2              0
# 309              1              2              2              1
#
# [1860 rows x 316 columns]

# %% [markdown]
# ## Outras tabelas
# - #### Prematura
# `get_data('prematura')`
# Muito semelhante a tabela por grupos etários
# - #### Mortalidate infantil
# `get_data('infantil')`
# Agregado por mês
# - #### Regiao de saude
# `get_data('ARS')`
# Not working

# %% [markdown]
# # TODO

# %% [markdown]
# - fix concelhos
# - fix dates, convert all to long or wide formats
# - remove ""
